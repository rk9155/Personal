# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome(executable_path = '/Users/rakeshcq/Downloads/chromedriver')
driver
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-11-c8222d905b7e> in <module>
# ----> 1 driver = webdriver.Chrome(executable_path = '/Users/rakeshcq/Downloads/chromedriver')
#       2 driver
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ...

# %%
driver.get('https://codingninjas.in')

# %%
driver.title
# Out:
# 'Learn Coding Online with Live 1:1 Mentor Support | Coding Ninjas'

# %%
driver.back()

# %%
driver.save_screenshot('test.png')
# Out:
# True

# %%
driver.page_source
# Out:
# '<html lang="en" style="--batchMonthBG:#FFEBC2; --batchCardBC:#FFEBC2; --batchMonthTC:#AC933C;"><head>\n    <meta charset="utf-8">\n    <title>Learn Coding Online with Live 1:1 Mentor Support | Coding Ninjas</title>\n\n    <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">\n    <meta name="title" content="Learn Coding Online with Live 1:1 Mentor Support | Coding Ninjas">\n    <meta property="og:title" content="Learn Coding Online with Live 1:1 Mentor Support | Coding Ninjas">\n    <meta name="description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:image" content="https://files.codingninjas.in/0000000000000723.jpg">\n
# ...

# %%
reg_btn = driver.find_element_by_link_text('Courses')
reg_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e956b49f5adc11796e654a738351da0b", element="a5be2a4c-06d2-44a0-b980-67a046d3250e")>

# %%
reg_btn.click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="e956b49f5adc11796e654a738351da0b", element="a5be2a4c-06d2-44a0-b980-67a046d3250e")>>

# %%
reg_btn.click()

# %%
driver.back()

# %%
driver.forward()

# %%
driver.get('https://www.google.com/')

# %%
driver.title
# Out:
# 'Google'

# %%
driver.get('http://kanview.ks.gov/PayRates/PayRates_Agency.aspx')
